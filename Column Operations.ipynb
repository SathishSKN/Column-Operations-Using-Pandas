# %% [markdown]
# # COLUMN OPERATION USING PANDAS

# %% [markdown]
# ### This dataset is downloaded from the Kaggle dataset website and used it to do some basic data exploration using pandas. This dataset contains the actions contained in a market area

# %%
import pandas as pd

# %% [markdown]
# #### To perform the operations we need to import a library, so here pandas library is imported locally as pd

# %%
Market=pd.read_csv("D:/MBA/SEM 2/Python/Datasets/market_fact.csv")
Market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %% [markdown]
# #### Use pd.read_csv function to read the dataset in to Jupyter Notebook

# %%
Market['Gross_Sales'] = Market['Sales'] + Market['Shipping_Cost']
Market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Gross_Sales
# 0                 23   -30.51           3.60                 0.56     140.4100
# ...

# %% [markdown]
# #### A new variable is added to the dataset with help of using the existing variables

# %%
Market.rename(columns = {'Sales' : 'Sales_Amount'})
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id  Sales_Amount  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818      136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818       42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818     4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818     2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818     4233.1500      0.08
# ...        ...      ...       ...        ...           ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798     2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798      127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798      243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798     3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798      603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Gross_Sales
# ...

# %% [markdown]
# #### A single variable name is renamed here using rename function

# %%
Market.rename(columns = {'Sales' : 'Sales_Amount','Prod_id' : 'Product_id','Ship_id' : 'Shipping_id'})
# Out:
#         Ord_id Product_id Shipping_id    Cust_id  Sales_Amount  Discount  \
# 0     Ord_5446    Prod_16    SHP_7609  Cust_1818      136.8100      0.01
# 1     Ord_5406    Prod_13    SHP_7549  Cust_1818       42.2700      0.01
# 2     Ord_5446     Prod_4    SHP_7610  Cust_1818     4701.6900      0.00
# 3     Ord_5456     Prod_6    SHP_7625  Cust_1818     2337.8900      0.09
# 4     Ord_5485    Prod_17    SHP_7664  Cust_1818     4233.1500      0.08
# ...        ...        ...         ...        ...           ...       ...
# 8394  Ord_5353     Prod_4    SHP_7479  Cust_1798     2841.4395      0.08
# 8395  Ord_5411     Prod_6    SHP_7555  Cust_1798      127.1600      0.10
# 8396  Ord_5388     Prod_6    SHP_7524  Cust_1798      243.0500      0.02
# 8397  Ord_5348    Prod_15    SHP_7469  Cust_1798     3872.8700      0.03
# 8398  Ord_5459     Prod_6    SHP_7628  Cust_1798      603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Gross_Sales
# ...

# %% [markdown]
# #### Multiple variable name is renamed here using rename function

# %%
Market.drop(['Gross_Sales'], axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %% [markdown]
# #### A single variable is removed using the drop function

# %%
Market.drop(['Gross_Sales','Order_Quantity','Product_Base_Margin'], axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount   Profit  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01   -30.51
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01     4.56
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00  1148.90
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09   729.34
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08  1219.87
# ...        ...      ...       ...        ...        ...       ...      ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08   374.63
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10   -74.03
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02   -70.85
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03   565.34
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00   131.39
#
#       Shipping_Cost
# 0              3.60
# 1              0.93
# ...

# %% [markdown]
# #### Multiple variable is removed using the drop function

# %%
Market.columns = [col.upper() for col in Market.columns]
Market
# Out:
#         ORD_ID  PROD_ID   SHIP_ID    CUST_ID      SALES  DISCOUNT  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       ORDER_QUANTITY   PROFIT  SHIPPING_COST  PRODUCT_BASE_MARGIN  GROSS_SALES
# 0                 23   -30.51           3.60                 0.56     140.4100
# ...

# %% [markdown]
# #### Uppercase of columns name

# %%
Market.columns = [col.lower() for col in Market.columns]
Market
# Out:
#         ord_id  prod_id   ship_id    cust_id      sales  discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       order_quantity   profit  shipping_cost  product_base_margin  gross_sales
# 0                 23   -30.51           3.60                 0.56     140.4100
# ...

# %% [markdown]
# #### Lowercase of coulmns name

# %%
Market.sort_values(by = 'cust_id', ascending = True)
# Out:
#         ord_id  prod_id   ship_id   cust_id     sales  discount  \
# 5858     Ord_1   Prod_1     SHP_1    Cust_1   261.540      0.04
# 1770    Ord_10   Prod_3    SHP_13   Cust_10    80.610      0.02
# 1507   Ord_271   Prod_5   SHP_369  Cust_100  2522.210      0.00
# 1506   Ord_271  Prod_17   SHP_370  Cust_100  4181.820      0.01
# 1505   Ord_227   Prod_7   SHP_315  Cust_100   181.780      0.02
# ...        ...      ...       ...       ...       ...       ...
# 7053  Ord_2612   Prod_6  SHP_3574  Cust_999   193.160      0.03
# 7054  Ord_2588   Prod_2  SHP_3543  Cust_999   508.730      0.08
# 7055  Ord_2685   Prod_4  SHP_3676  Cust_999   617.219      0.03
# 7048  Ord_2827   Prod_6  SHP_3889  Cust_999   614.910      0.02
# 7040  Ord_2668   Prod_2  SHP_3654  Cust_999    78.790      0.03
#
#       order_quantity   profit  shipping_cost  product_base_margin  gross_sales
# 5858               6  -213.25          35.00                 0.80      296.540
# ...

# %% [markdown]
# #### Sorting for a single variable

# %%
Market.sort_values(by = ['cust_id','prod_id'], ascending =[True,False])
# Out:
#         ord_id  prod_id   ship_id   cust_id     sales  discount  \
# 5858     Ord_1   Prod_1     SHP_1    Cust_1   261.540      0.04
# 1770    Ord_10   Prod_3    SHP_13   Cust_10    80.610      0.02
# 1504   Ord_219   Prod_7   SHP_305  Cust_100   148.170      0.00
# 1505   Ord_227   Prod_7   SHP_315  Cust_100   181.780      0.02
# 1503   Ord_163   Prod_5   SHP_220  Cust_100    34.110      0.02
# ...        ...      ...       ...       ...       ...       ...
# 7054  Ord_2588   Prod_2  SHP_3543  Cust_999   508.730      0.08
# 7045  Ord_2637  Prod_15  SHP_3607  Cust_999   379.800      0.02
# 7051  Ord_2637  Prod_13  SHP_3608  Cust_999   107.700      0.06
# 7037  Ord_2810  Prod_12  SHP_3868  Cust_999   180.480      0.01
# 7044  Ord_2687  Prod_11  SHP_3679  Cust_999  3049.632      0.04
#
#       order_quantity  profit  shipping_cost  product_base_margin  gross_sales
# 5858               6 -213.25          35.00                 0.80      296.540
# ...

# %% [markdown]
# #### Sorting multiple variables using sort function

# %%
Market.drop(['ord_id','ship_id','shipping_cost'], axis=1,inplace = True)
Market
# Out:
#       prod_id    cust_id      sales  discount  order_quantity   profit  \
# 0     Prod_16  Cust_1818   136.8100      0.01              23   -30.51
# 1     Prod_13  Cust_1818    42.2700      0.01              13     4.56
# 2      Prod_4  Cust_1818  4701.6900      0.00              26  1148.90
# 3      Prod_6  Cust_1818  2337.8900      0.09              43   729.34
# 4     Prod_17  Cust_1818  4233.1500      0.08              35  1219.87
# ...       ...        ...        ...       ...             ...      ...
# 8394   Prod_4  Cust_1798  2841.4395      0.08              28   374.63
# 8395   Prod_6  Cust_1798   127.1600      0.10              20   -74.03
# 8396   Prod_6  Cust_1798   243.0500      0.02              39   -70.85
# 8397  Prod_15  Cust_1798  3872.8700      0.03              23   565.34
# 8398   Prod_6  Cust_1798   603.6900      0.00              47   131.39
#
#       product_base_margin  gross_sales
# 0                    0.56     140.4100
# ...

# %% [markdown]
# #### Multiple variable is removed using the drop function

# %%
Market.groupby('cust_id').count()
# Out:
#            prod_id  sales  discount  order_quantity  profit  \
# cust_id
# Cust_1           1      1         1               1       1
# Cust_10          1      1         1               1       1
# Cust_100         6      6         6               6       6
# Cust_1000        7      7         7               7       7
# Cust_1001       10     10        10              10      10
# ...            ...    ...       ...             ...     ...
# Cust_995        12     12        12              12      12
# Cust_996         5      5         5               5       5
# Cust_997        10     10        10              10      10
# Cust_998         4      4         4               4       4
# Cust_999        20     20        20              20      20
#
#            product_base_margin  gross_sales
# cust_id
# Cust_1                       1            1
# Cust_10                      1            1
# Cust_100                     6            6
# Cust_1000                    7            7
# ...

# %% [markdown]
# #### Group by using a single variable

# %%
Market=pd.read_csv("D:/MBA/SEM 2/Python/Datasets/market_fact.csv")
Market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %% [markdown]
# #### Use pd.read_csv function to read the dataset in to Jupyter Notebook

# %%
print(Market['Ord_id'].isnull().sum())
# Out:
# 0

# %% [markdown]
# #### Isnull function used to check if there is any null values in the dataset

# %%
len(Market.columns.values)
# Out:
# 10

# %% [markdown]
# #### Length of a dataframe

# %%
Market.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %% [markdown]
# #### Column function used to view the variables names

# %%
Market.columns.values
# Out:
# array(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype=object)

# %% [markdown]
# #### Column.values function also used to view the variables names
